# %%
import pandas as pd
import getpass
import torch
import soundfile as sf
from IPython.display import Audio
from pyannote.audio import Pipeline
# Out:
# /home/ubuntu/anaconda3/envs/speaker_diarization/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
dataset = pd.read_csv('diarized_tag_afrispeech_dialog_v1.1_49.csv')

# %%
HUGGINGFACE_ACCESS_TOKEN = getpass.getpass(prompt="Enter huggingface access token: ")
# Out:
# Enter huggingface access token: ········

# %%
def merge_consecutive_segments(diarization):
  merged_segments = []
  last_start, last_end, last_speaker = None, None, None

  for turn, _, speaker in diarization.itertracks(yield_label=True):
      start_time = turn.start
      end_time = turn.end

      #check if the current segment should be merged with the previous one
      if last_speaker is not None and speaker == last_speaker:
          #extend the end time of the last segment
          last_end = end_time
      else:
          #if it's not the first iteration and there's a previous segment to save
          if last_speaker is not None:
              merged_segments.append((last_start, last_end, last_speaker))
          #update last segment trackers
          last_start, last_end, last_speaker = start_time, end_time, speaker

  #add the last segment after exiting the loop
  if last_speaker is not None:
      merged_segments.append((last_start, last_end, last_speaker))

  return merged_segments

# %%
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1", use_auth_token=HUGGINGFACE_ACCESS_TOKEN)
pipeline.to(torch.device("cuda"))

# %%
diarization = pipeline("/data3/mardhiyah/AfriSpeech-Dialog/data/medical/247554f8-f233-4861-bc1a-8fc327b5d5df_2b500b633e5d5ecce35433cbbb859ddc_8bW4oSXn.wav")
pred_segments = merge_consecutive_segments(diarization)

# %%
pred_segments
# Out:
# [(0.70596875, 7.06784375, 'SPEAKER_01'),
#  (7.06784375, 9.632843750000003, 'SPEAKER_00'),
#  (9.66659375, 10.392218750000001, 'SPEAKER_01'),
#  (10.45971875, 12.214718750000003, 'SPEAKER_00'),
#  (12.29909375, 16.90596875, 'SPEAKER_01'),
#  (17.17596875, 19.90971875, 'SPEAKER_00'),
#  (19.90971875, 20.550968750000003, 'SPEAKER_01'),
#  (20.027843750000002, 25.191593750000003, 'SPEAKER_00'),
#  (25.44471875, 32.17784375, 'SPEAKER_01'),
#  (32.59971875, 39.41721875, 'SPEAKER_00'),
#  (39.41721875, 41.57721875, 'SPEAKER_01'),
#  (41.13846875, 42.64034375, 'SPEAKER_00'),
#  (42.336593750000006, 54.250343750000006, 'SPEAKER_01'),
#  (54.55409375, 60.35909375000001, 'SPEAKER_00'),
#  (60.51096875, 67.73346875, 'SPEAKER_01'),
#  (68.77971875, 71.54721875, 'SPEAKER_00'),
#  (71.54721875, 72.45846875000001, 'SPEAKER_01'),
#  (72.03659375000001, 73.11659375, 'SPEAKER_00'),
#  (73.74096875000001, 78.21284375, 'SPEAKER_01'),
#  (78.75284375000001, 86.48159375, 'SPEAKER_00'),
#  (80.55846875, 91.79721875, 'SPEAKER_01'),
#  (92.59034375, 93.34971875000001, 'SPEAKER_00'),
#  (93.38346875, 100.87596875000001, 'SPEAKER_01'),
#  (101.87159375, 102.69846875, 'SPEAKER_00'),
#  (103.40721875000001, 106.96784375, 'SPEAKER_01'),
#  (107.49096875000001, 108.26721875000001, 'SPEAKER_00'),
#  (108.55409375, 117.83534375, 'SPEAKER_01'),
#  (117.97034375000001, 119.47221875000001, 'SPEAKER_00'),
#  (121.14284375000001, 121.88534375, 'SPEAKER_01'),
#  (121.88534375, 121.90221875, 'SPEAKER_00'),
#  (124.14659375000001, 125.26034375, 'SPEAKER_01'),
#  (126.17159375000001, 126.86346875000001, 'SPEAKER_00'),
#  (127.53846875, 131.20034375, 'SPEAKER_01'),
#  (131.87534375, 132.60096875000002, 'SPEAKER_00'),
#  (132.71909375, 136.19534375, 'SPEAKER_01'),
#  (136.24596875, 137.02221875, 'SPEAKER_00'),
#  (137.20784375, 140.43096875, 'SPEAKER_01'),
#  (141.22409375, 142.06784375, 'SPEAKER_00'),
#  (142.50659375, 150.82596875000002, 'SPEAKER_01'),
#  (150.96096875, 152.05784375000002, 'SPEAKER_00'),
#  (152.09159375000002, 153.82971875, 'SPEAKER_01'),
#  (154.01534375, 157.12034375000002, 'SPEAKER_00'),
#  (159.76971875, 160.56284375, 'SPEAKER_01')]

# %%
def get_audio_duration(file_path):
    audio_data, sample_rate = sf.read(file_path)
    duration = len(audio_data) / sample_rate
    return duration

# %%
get_audio_duration('/data3/mardhiyah/AfriSpeech-Dialog/data/medical/247554f8-f233-4861-bc1a-8fc327b5d5df_2b500b633e5d5ecce35433cbbb859ddc_8bW4oSXn.wav')
# Out:
# 160.57199546485262

# %%
# dataset['path'] = dataset['path'].apply(lambda x: '/data3/mardhiyah/AfriSpeech-Dialog'+x)
dataset.head()
# Out:
#                                audio_id  \
# 0                                   NaN
# 1  f9bd30b2-684d-470e-b65c-ced156da0bbb
# 2  78fb7265-0373-49d5-b933-c28c95cf3eea
# 3                                   NaN
# 4                                   NaN
#
#                                                 path  \
# 0  /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 1  /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 2  /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 3  /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 4  /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
#
#                                           transcript age_group  gender  \
# 0  Speaker 1: My name is justina, I’m a medical d...     26-40    Male
# 1  \r\n\r\n00:04:08\r\n[Speaker 1]: Hi, I am Dr. ...     26-40  Female
# 2  00:01:06\r\n[Speaker 1]: Are you there?\r\n00:...     26-40    Male
# 3  [Speaker 1]: My name is dorathy and i am conse...     26-40    Male
# 4  [Speaker 1]: Hello. How are you?\r\n[Speaker 2...     26-40    Male
#
#    accent               domain country  audio_duration  \
# 0   Hausa  OSCE-Doctor-Patient      NG      240.000000
# 1  Yoruba  OSCE-Doctor-Patient      NG      235.932993
# 2  Yoruba  OSCE-Doctor-Patient      NG      906.433991
# 3   Hausa  OSCE-Doctor-Patient      NG      240.000000
# 4   Hausa  OSCE-Doctor-Patient      NG      240.000000
#
#                                       doctor_summary  all_timestamps
# 0  Joel Solomon is a 45-year-old male who has bee...           False
# 1  Habemuko, a 35 year old, presents with rectal ...           False
# 2  Mr. Ade, a 35 year old unmarried Yoruba male t...            True
# 3  Chidinma Okunmi, a 25 year old Igbo student, p...           False
# 4  Mr. Emeka is a 65 year old male who presents w...           False

# %%
diarize_dataset = dataset[dataset['all_timestamps']==True].reset_index()

# %%
# len(diarize_dataset)

# %%
from tqdm import tqdm

diarize_dataset['pred_segments'] = ''
for i, path_ in tqdm(enumerate(diarize_dataset['path']), total=len(diarize_dataset['path']), desc="Processing"):
    diarization = pipeline(path_)
    pred_segments = merge_consecutive_segments(diarization)
    
    diarize_dataset.at[i, 'pred_segments'] = pred_segments
# Out:
# Processing:  30%|████████▍                   | 10/33 [30:48<1:10:51, 184.83s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 4>()
#       3 diarize_dataset['pred_segments'] = ''
#       4 for i, path_ in tqdm(enumerate(diarize_dataset['path']), total=len(diarize_dataset['path']), desc="Processing"):
# ----> 5     diarization = pipeline(path_)
#       6     pred_segments = merge_consecutive_segments(diarization)
#       8     diarize_dataset.at[i, 'pred_segments'] = pred_segments
#
# File ~/anaconda3/envs/speaker_diarization/lib/python3.10/site-packages/pyannote/audio/core/pipeline.py:321, in Pipeline.__call__(self, file, **kwargs)
#     312         raise RuntimeError(
#     313             "A pipeline must be instantiated with `pipeline.instantiate(paramaters)` before it can be applied. "
#     314             "Tried to use parameters provided by `pipeline.default_parameters()` but those are not compatible. "
#     315         )
#     317     warnings.warn(
#     318         f"The pipeline has been automatically instantiated with {default_parameters}."
#     319     )
# --> 321 file = Audio.validate_file(file)
#     323 if hasattr(self, "preprocessors"):
#     324     file = ProtocolFile(file, lazy=self.preprocessors)
#
# File ~/anaconda3/envs/speaker_diarization/lib/python3.10/site-packages/pyannote/audio/core/io.py:171, in Audio.validate_file(file)
#     169     path = Path(file["audio"])
#     170     if not path.is_file():
# --> 171         raise ValueError(f"File {path} does not exist")
#     173     file.setdefault("uri", path.stem)
#     175 else:
#
# ValueError: File /data3/mardhiyah/AfriSpeech-Dialogdata/non-medical/30a5b6a2-8370-4dac-bc7f-e4ae7c1d8562_a4a6daf501c5da95d8f941189e8b6856_NowwEqPI.wav does not exist

# %%
medical_diarized_ds = diarize_dataset[diarize_dataset['domain']!='OSCE-Doctor-Patient'].reset_index()
medical_diarized_ds['path'] = medical_diarized_ds['path'].apply(lambda x: str(x).replace('Dialogdata', 'Dialog/data'))

# %%
medical_diarized_ds['pred_segments'] = ''
for i, path_ in tqdm(enumerate(medical_diarized_ds['path']), total=len(medical_diarized_ds['path']), desc="Processing"):
    diarization = pipeline(path_)
    pred_segments = merge_consecutive_segments(diarization)
    
    medical_diarized_ds.at[i, 'pred_segments'] = pred_segments
# Out:
# Processing: 100%|████████████████████████████| 23/23 [2:03:16<00:00, 321.60s/it]

# %%
osce_diarized_ds = diarize_dataset[diarize_dataset['domain']=='OSCE-Doctor-Patient'].reset_index()

# %%
#join the dataframes back together vertically
result = pd.concat([osce_diarized_ds, medical_diarized_ds], axis=0, ignore_index=True).reset_index()

# %%
# result.drop(columns=['level_0'], inplace=True)

# %%
#confirm 1, 26, 28 are the incomplete diarization and then remove them
# print(result.iloc[28]['transcript'])
final_diarized_ds = result.drop(index=[1,26,28]).reset_index(drop=True)

# %%
def convert_time_to_seconds(timestamp):
    # Split the timestamp into minutes, seconds, and milliseconds
    minutes, seconds, milliseconds = map(float, timestamp.split(':'))
    # Convert the time to seconds (including fractional part from milliseconds)
    total_seconds = minutes * 60 + seconds + milliseconds / 1000
    return total_seconds


def extract_segments(transcript):
    # Regular expression to match the timestamp and speaker tag
    timestamp_pattern = r'(\d{2}:\d{2}:\d{2})'
    speaker_pattern = r'\[([^\]]+)\]'
    
    lines = transcript.strip().splitlines()
    segments = []
    
    start_time = None
    speaker_tag = None
    
    for i in range(len(lines)):
        if re.match(timestamp_pattern, lines[i]):  # Line is a timestamp
            if start_time and speaker_tag:
                # If we have both start and speaker, the current timestamp is the end time
                end_time = convert_time_to_seconds(lines[i])
                segments.append((start_time, end_time, speaker_tag))
                start_time = None
                speaker_tag = None
            # Set the new start time, converting to seconds
            start_time = convert_time_to_seconds(lines[i])
        elif re.match(speaker_pattern, lines[i]):  # Line contains a speaker tag
            speaker_tag = re.findall(speaker_pattern, lines[i])[0]
    
    return segments

# %%
#ensure new line before speaker tags
# final_diarized_ds['transcript'] = final_diarized_ds['transcript'].apply(lambda x: str(x).replace('[', '\r\n['))
final_diarized_ds['ref_segments'] = final_diarized_ds['transcript'].apply(lambda x: extract_segments(x))

# %%
final_diarized_ds
# Out:
#     index                              audio_id  \
# 0       2  78fb7265-0373-49d5-b933-c28c95cf3eea
# 1       6  6d5f1e84-dbc5-42d3-898e-bfe9c2cfe166
# 2      11  ab8fd39d-52bc-48fa-bae9-ff636627f1e5
# 3      12  5129fd8c-7b8c-4d05-a03a-196bcae4deff
# 4      13  58efe9ef-6c76-4d17-b1b2-f397552a0c0e
# 5      16  b6f48ed7-e629-4e50-af63-1c9067c34ef2
# 6      17  b9ffbd7f-d6a5-4511-a7aa-b1e0b52dfc03
# 7      18  f2905988-70f5-42a3-86db-19066b25bc48
# 8      19  9d1962f3-e879-452d-b57b-cf4a7f133cd8
# 9      20  a71d3ac2-bd1f-4a67-bbff-c9d8d678ae10
# 10     21  b38db6a7-91c7-42aa-825f-26a69311701e
# 11     22  756d9ca8-d56b-4340-9ba3-729274194b06
# 12     23  5256e7bc-db82-4507-a2dd-3a2d3056b8e7
# 13     24  b079b54a-0525-4e05-b51c-8ff47d256072
# 14     25  cc0c1c87-bdf8-409d-a305-7cec466b39c1
# 15     26  485be54f-1e4c-46e6-b3f8-d393ecbdcc3a
# 16     27  1ef840ba-47ed-43c0-873c-3d1f9a4e9f71
# 17     28  21d5b5a0-236a-4b9a-b4e8-aa75cdbb14d6
# 18     29  a274f473-e190-4a49-ad40-869298519654
# 19     30  41223b3d-3f9a-4384-850e-83aa2b072c7c
# 20     31  6fe3c7b1-69f1-4ab7-92b3-b583c6ac76bb
# 21     33  a63185e9-6157-4618-befa-bce5378b82c2
# 22     34  a4b94b89-eb5a-4513-9c00-636e60a676db
# 23     35  9f30ab0d-3078-4864-9a57-be162291d81e
# 24     37  0b57e9be-5d21-4605-9119-00478b21ea77
# 25     40  08a2be8d-76d1-465f-a4ed-7fc5a61056bf
# 26     43  b9c74d7e-7404-4696-9db7-d61107b1e449
# 27     45  8b20c03b-0633-4952-992a-a05d93de5391
# 28     46  c16ba577-6c51-4399-a1d7-e1375f9db83d
# 29     48  ee3c206b-81f9-49d2-bff3-2d4974daad64
#
#                                                  path  \
# 0   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 1   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 2   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 3   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 4   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 5   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 6   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 7   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 8   /data3/mardhiyah/AfriSpeech-Dialog/data/medica...
# 9   /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 10  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 11  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 12  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 13  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 14  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 15  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 16  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 17  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 18  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 19  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 20  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 21  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 22  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 23  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 24  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 25  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 26  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 27  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 28  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
# 29  /data3/mardhiyah/AfriSpeech-Dialog/data/non-me...
#
# 5      [(0.03096875, 219.11909375000002, SPEAKER_00)]
# 6   [(0.03096875, 4.334093750000001, SPEAKER_01), ...
# 7   [(3.9797187500000004, 11.82659375, SPEAKER_01)...
# 8   [(0.03096875, 15.454718750000001, SPEAKER_00),...
# 9   [(0.8072187500000001, 4.11471875, SPEAKER_00),...
# 10  [(0.60471875, 6.814718750000001, SPEAKER_01), ...
# 11      [(1.56659375, 554.6615937500001, SPEAKER_00)]
# 12  [(0.03096875, 3.84471875, SPEAKER_01), (4.1822...
# 13  [(0.03096875, 3.2372187500000003, SPEAKER_00),...
# 14  [(0.03096875, 4.384718750000001, SPEAKER_00), ...
# 15  [(0.03096875, 29.039093750000003, SPEAKER_00),...
# 16  [(1.41471875, 8.687843750000003, SPEAKER_00), ...
# 17  [(0.03096875, 9.177218750000002, SPEAKER_01), ...
# 18  [(0.79034375, 30.000968750000002, SPEAKER_00),...
# 19  [(0.03096875, 3.6253437500000003, SPEAKER_01),...
# 20  [(0.03096875, 4.50284375, SPEAKER_00), (3.6253...
# 21  [(0.03096875, 3.57471875, SPEAKER_00), (4.2497...
# 22  [(0.03096875, 4.48596875, SPEAKER_00), (5.3297...
# 23  [(0.03096875, 4.6715937499999995, SPEAKER_00),...
# 24  [(0.03096875, 4.620968749999999, SPEAKER_01), ...
# 25  [(0.03096875, 5.835968750000001, SPEAKER_01), ...
# 26  [(0.03096875, 4.8572187499999995, SPEAKER_00),...
# 27  [(0.03096875, 6.2915937500000005, SPEAKER_00),...
# 28  [(0.03096875, 6.64596875, SPEAKER_01), (7.2703...
# 29  [(0.03096875, 4.90784375, SPEAKER_00), (5.7853...
#
#                                          ref_segments
# 0   [(1.006, 1.027, Speaker 1), (4.0, 8.038, Speak...
# 1   [(0.006, 2.028, Speaker 1), (2.049, 6.009, Spe...
# 2   [(0.008, 2.04, Speaker 1), (2.049, 5.023, Spea...
# 3   [(0.05, 3.044, Speaker 1), (4.016, 6.035, Spea...
# 4   [(1.013, 5.006, Speaker 1), (5.028, 6.028, Spe...
# 5   [(0.035, 1.022, Speaker 1), (2.016, 2.053, Spe...
# 6   [(0.008, 4.011, Speaker 1), (5.01, 9.045, Spea...
# 7   [(5.034, 11.059, Speaker 1), (12.042, 15.038, ...
# 8   [(0.004, 3.025, Speaker 1), (3.037, 6.025, Spe...
# 9   [(0.052, 4.006, Speaker 1), (4.052, 9.022, Spe...
# 10  [(0.037, 6.048, Speaker 1), (7.035, 11.029, Sp...
# 11  [(2.024, 8.001, Speaker 1), (9.059, 15.009, Sp...
# 12  [(1.029, 4.026, Speaker 1), (5.053, 8.039, Spe...
# 13  [(3.003, 3.025, Speaker 1), (3.025, 5.051, Spe...
# 14  [(1.001, 4.028, Speaker 1), (5.049, 8.022, Spe...
# 15  [(0.005, 7.0, Speaker 1), (7.012, 9.042, Speak...
# 16  [(1.005, 8.036, Speaker 1), (10.017, 16.03, Sp...
# 17  [(0.028, 5.033, Speaker 1), (5.054, 8.057, Spe...
# 18  [(0.05, 3.047, Speaker 1), (3.056, 6.042, Spea...
# 19  [(0.055, 3.04, Speaker 1), (4.011, 7.036, Spea...
# 20  [(4.037, 4.039, Speaker 1), (4.039, 11.056, Sp...
# 21  [(0.001, 3.034, Speaker 1), (4.023, 7.033, Spe...
# 22  [(4.023, 5.024, Speaker 1), (5.024, 11.028, Sp...
# 23  [(0.005, 4.029, Speaker 1), (5.016, 10.001, Sp...
# 24  [(4.028, 5.033, Speaker 1), (5.033, 10.03, Spe...
# 25  [(1.022, 6.038, Speaker 1), (6.038, 11.052, Sp...
# 26  [(4.056, 5.054, Speaker 1), (5.054, 10.047, Sp...
# 27  [(6.033, 7.01, Speaker 1), (7.01, 11.054, Spea...
# 28  [(0.033, 6.039, Speaker 1), (7.023, 11.037, Sp...
# 29  [(0.001, 4.053, Speaker 1), (5.055, 10.03, Spe...

# %% [markdown]
# Calculate Metrics

# %%
from pyannote.core import Annotation, Segment
from pyannote.metrics.diarization import DiarizationErrorRate

def create_pyannote_annotation(segments_list):
    annotation = Annotation()
    for start, end, speaker_tag in segments_list:
        segment = Segment(start, end)
        annotation[segment] = speaker_tag    
    return annotation

der_metric = DiarizationErrorRate()

# %%
for i, text in tqdm(enumerate(final_diarized_ds['transcript']), total=len(final_diarized_ds['transcript']), desc="Processing"):
    ref_annotation = create_pyannote_annotation(final_diarized_ds.iloc[i]['ref_segments'])
    pred_annotation = create_pyannote_annotation(final_diarized_ds.iloc[i]['pred_segments'])
    der = der_metric(ref_annotation, pred_annotation)
    print(f"DER: {100 * der:.2f}%")
#get abs value for whole dataset
ds_der = abs(der_metric)
print(f"Absolute DER for dataset: {100 * ds_der:.2f}%")
# Out:
# Processing:   0%|                                        | 0/30 [00:00<?, ?it/s]
# DER: 22.31%
# DER: 41.62%
# Processing:   7%|██▏                             | 2/30 [00:00<00:01, 17.78it/s]
# DER: 29.10%
# DER: 46.78%
# DER: 44.84%
# Processing:  17%|█████▎                          | 5/30 [00:00<00:01, 23.89it/s]
# DER: 40.92%
# DER: 16.47%
# DER: 21.34%
# DER: 40.81%
# DER: 5.27%
# DER: 33.09%
# Processing:  37%|███████████▎                   | 11/30 [00:00<00:00, 37.34it/s]
# DER: 48.95%
# DER: 4.27%
# DER: 8.38%
# DER: 7.48%
# DER: 44.95%
# DER: 7.35%
# DER: 15.80%
# DER: 27.63%
# DER: 1.47%
# DER: 10.45%
# Processing:  70%|█████████████████████▋         | 21/30 [00:00<00:00, 60.43it/s]
# DER: 51.84%
# DER: 2.56%
# DER: 5.71%
# DER: 23.69%
# DER: 1.95%
# DER: 7.51%
# DER: 37.14%
# DER: 3.25%
# DER: 48.28%
# Processing: 100%|███████████████████████████████| 30/30 [00:00<00:00, 56.13it/s]
# Absolute DER for dataset: 21.30%

# %%
final_diarized_ds.to_csv('pyannote_diarization_der_0.2130_30.csv', index=False)
